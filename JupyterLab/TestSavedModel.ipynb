# %%
import tensorflow as tf
import cv2
import os
import numpy as np
from matplotlib import pyplot as plt
import imghdr
from tensorflow.keras.models import load_model
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Dense, Flatten, Dropout
from tensorflow.keras.metrics import Precision, Recall, BinaryAccuracy

# %%
new_model = load_model(os.path.join('models','newclassificationModel.h5'))

# %%
testImg = cv2.imread('test.jpg')
testImg1 = cv2.cvtColor(testImg, cv2.COLOR_BGR2RGB)
testImg2 = tf.image.resize(testImg1, (256,256))
plt.imshow(testImg2.numpy().astype(int))

# %%
prediction = new_model.predict(np.expand_dims(testImg2/255,0)) 
print(prediction)
# Out:
# 1/1 [==============================] - 0s 106ms/step
# [[0.99983495]]

# %%
if prediction > 0.5: 
    print(f'Predicted class is Brick')
else:
    print(f'Predicted class is NOT Brick')
# Out:
# Predicted class is Brick

# %%
#Another example

# %%
testImg = cv2.imread('swordTest.png')
testImg1 = cv2.cvtColor(testImg, cv2.COLOR_BGR2RGB)
testImg2 = tf.image.resize(testImg1, (256,256))
plt.imshow(testImg2.numpy().astype(int))
prediction = new_model.predict(np.expand_dims(testImg2/255,0)) 
print(prediction)
if prediction > 0.5: 
    print(f'Predicted class is Brick')
else:
    print(f'Predicted class is NOT Brick')
# Out:
# 1/1 [==============================] - 0s 29ms/step
# [[0.01804771]]
# Predicted class is NOT Brick

# %%
#Another example

# %%
testImg = cv2.imread('6brick.jpg')
testImg1 = cv2.cvtColor(testImg, cv2.COLOR_BGR2RGB)
testImg2 = tf.image.resize(testImg1, (256,256))
plt.imshow(testImg2.numpy().astype(int))
prediction = new_model.predict(np.expand_dims(testImg2/255,0)) 
print(prediction)
if prediction > 0.5: 
    print(f'Predicted class is Brick')
else:
    print(f'Predicted class is NOT Brick')
# Out:
# 1/1 [==============================] - 0s 25ms/step
# [[0.9930839]]
# Predicted class is Brick

# %%
#Another example

# %%
testImg = cv2.imread('color.jpg')
testImg1 = cv2.cvtColor(testImg, cv2.COLOR_BGR2RGB)
testImg2 = tf.image.resize(testImg1, (256,256))
plt.imshow(testImg2.numpy().astype(int))
prediction = new_model.predict(np.expand_dims(testImg2/255,0)) 
print(prediction)
if prediction > 0.5: 
    print(f'Predicted class is Brick')
else:
    print(f'Predicted class is NOT Brick')
# Out:
# 1/1 [==============================] - 0s 31ms/step
# [[1.890831e-11]]
# Predicted class is NOT Brick
